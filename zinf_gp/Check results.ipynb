# %%
import os
import sys
from glob import glob

import numpy as np
import pandas as pd
idx = pd.IndexSlice
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

import pickle
import copy

import geopandas as gpd

from sklearn.metrics import mean_absolute_error

from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor

import gpflow
import tensorflow as tf

import pickle
from math import radians, cos, sin, asin, sqrt

code_dir = '/cluster/home/kheuto01/code/zero-inflated-gp/'
sys.path.append(code_dir)
from onoffgpf import OnOffSVGP, OnOffLikelihood

import pickle
import glob
# Out:
# /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
with open('/cluster/tufts/hugheslab/kheuto01/opioid/logs/qtr/ind1000_iter500/res.pkl','rb') as infile: 
    res = pickle.load(infile)

# %%
res
# Out:
# ([0.38898636137360043,
#   0.38275152094365666,
#   0.3803338738551602,
#   0.3862804559523647],
#  [(27.0, 0.15625, 27.0, 0.15625),
#   (22.0, 0.18518518518518517, 22.0, 0.18518518518518517),
#   (29.0, 0.12121212121212122, 29.0, 0.12121212121212116),
#   (26.0, 0.13333333333333333, 26.0, 0.1333333333333333)],
#  [(85.0, 0.24107142857142858, 85.0, 0.2410714285714285),
#   (76.0, 0.2897196261682243, 76.0, 0.2897196261682243),
#   (86.0, 0.24561403508771928, 86.0, 0.2456140350877192),
#   (84.0, 0.25, 84.0, 0.25)],
#  [(115.0, 0.3235294117647059, 115.0, 0.3235294117647059),
#   (118.0, 0.30994152046783624, 118.0, 0.30994152046783624),
#   (137.0, 0.26737967914438504, 137.0, 0.26737967914438515),
#   (133.0, 0.2611111111111111, 133.0, 0.2611111111111111)])

# %%
with open('/cluster/tufts/hugheslab/kheuto01/opioid/logs/qtr/ind1000_iter1000/res.pkl','rb') as infile: 
    res = pickle.load(infile)

# %%
res
# Out:
# ([0.41016259107615494,
#   0.4016405670574302,
#   0.3987484963403378,
#   0.39858712036129507],
#  [(29.0, 0.09375, 29.0, 0.09375),
#   (24.0, 0.1111111111111111, 24.0, 0.11111111111111115),
#   (33.0, 0.0, 33.0, 0.0),
#   (28.0, 0.06666666666666667, 28.0, 0.06666666666666665)],
#  [(89.0, 0.20535714285714285, 89.0, 0.2053571428571428),
#   (91.0, 0.14953271028037382, 91.0, 0.1495327102803738),
#   (99.0, 0.13157894736842105, 99.0, 0.13157894736842105),
#   (87.0, 0.22321428571428573, 87.0, 0.22321428571428567)],
#  [(123.0, 0.27647058823529413, 123.0, 0.2764705882352941),
#   (135.0, 0.21052631578947367, 135.0, 0.21052631578947364),
#   (144.0, 0.22994652406417113, 144.0, 0.22994652406417115),
#   (134.0, 0.25555555555555554, 134.0, 0.25555555555555554)])

# %%
with open('/cluster/tufts/hugheslab/kheuto01/opioid/logs/qtr/ind1000_iter500/model.pkl','rb') as infile: 
    res = pickle.load(infile)

# %%
res
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.Zf</td><td>[[ 4.17406593e+01 -7.10588543e+01  7.54066337e+01 ...  6.47567407e-01</br>   1.19272443e+00 -1.87853305e-01]</br> [ 4.19031561e+01 -7.05938250e+01  5.20349646e+01 ...  5.79079186e-01</br>   4.85871082e-01  1.64748146e-02]</br> [ 4.24777510e+01 -7.11709294e+01  6.99300492e+01 ...  5.62809362e-01</br>   7.79864354e-01  7.00647369e-01]</br> ...</br> [ 4.22836318e+01 -7.22776724e+01  3.98885220e+00 ...  1.86673859e-01</br>   9.03239573e-01 -2.01612315e-02]</br> [ 4.15478957e+01 -7.11274543e+01  1.99887204e+01 ...  4.63105522e-01</br>   4.09064302e-01  9.70860531e-01]</br> [ 4.17744415e+01 -7.09311938e+01  8.54639745e-01 ... -4.98893088e-01</br>   2.07230464e+00  1.84789889e-01]]</td><td>None</td><td>(none)</td></tr><tr><td>model.Zg</td><td>[[ 42.63145897 -71.37615728  75.10979061 ...   0.80213599   1.45196574</br>   -0.74121364]</br> [ 42.16271208 -70.81084848  52.
# ...

# %%
files = glob.glob('/cluster/tufts/hugheslab/kheuto01/opioid/logs/qtr/*/model.pkl')
best_elbo = -60000
for file in files:
    with open(file,'rb') as infile: 
        res = pickle.load(infile)
        
    # mae = np.mean(res[0])
    #xtop = np.mean([thing[-1] for thing in res[-1]])
    elbo = res.compute_log_likelihood()
    if elbo > best_elbo:
        best_elbo=elbo
        best_file=file
    #print(f'{mae}, {xtop}')
    #if xtop>0.34:
    #    print(file)
    #    print(res[-1])
# Out:
# WARNING:tensorflow:From /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/gpflow/param.py:616: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/gpflow/session.py:74: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/gpflow/param.py:653: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/gpflow/transforms.py:153: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
with open('/cluster/tufts/hugheslab/kheuto01/opioid/logs/qtr/ind100_iter3000/model.pkl','rb') as infile: 
    res = pickle.load(infile)

# %%
import gpflow

# %%
gpflow.__version__
# Out:
# '0.4.0'

# %%
best_file
# Out:
# '/cluster/tufts/hugheslab/kheuto01/opioid/logs/qtr/ind100_iter3000/model.pkl'

# %%
with open(file,'rb') as infile: 
    res = pickle.load(infile)

mae = np.mean(res[0])
xtop = np.mean([thing[-1] for thing in res[-1]])

print(f'{mae}, {xtop}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-655d65d742c2> in <module>
#       2     res = pickle.load(infile)
#       3
# ----> 4 mae = np.mean(res[0])
#       5 xtop = np.mean([thing[-1] for thing in res[-1]])
#       6
#
# TypeError: 'OnOffSVGP' object does not support indexing

# %%
res.compute_log_likelihood()
# Out:
# WARNING:tensorflow:From /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/gpflow/param.py:616: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/gpflow/session.py:74: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/gpflow/param.py:653: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /cluster/tufts/hugheslab/kheuto01/miniconda3/envs/zigp_36/lib/python3.6/site-packages/gpflow/transforms.py:153: The name tf.log is deprecated. Please use tf.math.log instead.
# -54807.28875939663
